# %% [markdown]
# #Use catalog

# %%
# %sql
USE CATALOG workspace

# %% [markdown]
# #Create schemas

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS bronzelayerschema
COMMENT 'BRONZE LAYER : raw data' ;

CREATE SCHEMA IF NOT EXISTS silverschema
COMMENT 'SILVER LAYER : cleaned/transformed data' ;

CREATE SCHEMA IF NOT EXISTS goldschema
COMMENT 'GOLD LAYER : business-ready data' ;

# %% [markdown]
# #Create volume

# %%
# %sql
CREATE VOLUME IF NOT EXISTS workspace.
COMMENT 'Raw data sources' ;
